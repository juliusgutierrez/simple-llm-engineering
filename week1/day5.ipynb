# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/blog/inference-providers',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-R1',
#  '/Zyphra/Zonos-v0.1-hybrid',
#  '/agentica-org/DeepScaleR-1.5B-Preview',
#  '/microsoft/OmniParser-v2.0',
#  '/Zyphra/Zonos-v0.1-transformer',
#  '/models',
#  '/spaces/lllyasviel/LuminaBrush',
#  '/spaces/black-forest-labs/FLUX.1-dev',
#  '/spaces/m-ric/open_Deep-Research',
#  '/spaces/tencent/Hunyuan3D-2',
#  '/spaces/webml-community/kokoro-webgpu',
#  '/spaces',
#  '/datasets/open-r1/OpenR1-Math-220k',
#  '/datasets/saiyan-world/Goku-MovieGenBench',
#  '/datasets/open-thoughts/OpenThoughts-114k',
#  '/datasets/Anthropic/EconomicIndex',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/peft',
#  '/docs/transformers.js',
#  '/docs/timm',
#  '/docs/trl',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blogs page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Welcome to Inference Providers on the Hub 🔥
# smolagents - a smol library to build great agents
# Use models from the HF Hub in LM Studio
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1
# Updated
# 8 days ago
# •
# 3.98M
# •
# 9.22k
# Zyphra/Zonos-v0.1-hybrid
# Updated
# 2 days ago
# •
# 12k
# •
# 849
# agentica-org/DeepScaleR-1.5B-Preview
# Updated
# 6 days ago
# •
# 8.91k
# •
# 388
# microsoft/OmniParser-v2.0
# Updated
# 3 days ago
# •
# 230
# •
# 304
# Zyphra/Zonos-v0.1-transformer
# Updated
# 2 days ago
# •
# 30.5k
# •
# 283
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 427
# 427
# LuminaBrush
# 📈
# Execute custom code from environment variable
# Running
# on
# Zero
# 7.17k
# 7.17k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Running
# on
# CPU Upgrade
# 365
# 365
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# Running
# on
# Zero
# 1.62k
# 1.62k
# Hunyuan3D-2.0
# 🌍
# Text-to-3D and Image-to-3D Generation
# Running
# 254
# 254
# Kokoro Text-to-Speech (WebGPU)
# 🗣
# High-quality speech synthesis powered by Kokoro TTS
# Browse 400k+ applications
# Datasets
# open-r1/OpenR1-Math-220k
# Updated
# 5 days ago
# •
# 2.43k
# •
# 313
# saiyan-world/Goku-MovieGenBench
# Updated
# 6 days ago
# •
# 19k
# •
# 160
# open-thoughts/OpenThoughts-114k
# Updated
# 3 days ago
# •
# 52.3k
# •
# 513
# Anthropic/EconomicIndex
# Updated
# 7 days ago
# •
# 4.17k
# •
# 129
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 9.6k
# •
# 7.51k
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 388 models
# •
# 2.26k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.57k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.72k followers
# Google
# company
# •
# 913 models
# •
# 7.61k followers
# Intel
# company
# •
# 218 models
# •
# 2.25k followers
# Microsoft
# company
# •
# 355 models
# •
# 8.47k followers
# Grammarly
# company
# •
# 10 models
# •
# 125 followers
# Writer
# Enterprise
# company
# •
# 18 models
# •
# 235 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 139,097
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 27,473
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 3,090
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,320
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,364
# Fast tokenizers, optimized for both research and production.
# PEFT
# 17,263
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,903
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 33,125
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 11,499
# Train transformer language models with reinforcement learning.
# Datasets
# 19,600
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,734
# Toolkit to serve Large Language Models.
# Accelerate
# 8,302
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 20,316
# AI & ML interests
# The AI community building the future.
# Recent Activity
# sayakpaul
# updated
# a dataset
# 1 day ago
# huggingface/diffusers-metadata
# giadap
# authored
# a paper
# 7 days ago
# Fully Autonomous AI Agents Should Not be Developed
# glutamatt
# authored
# a paper
# 11 days ago
# SmolLM2: When Smol Goes Big -- Data-Centric Training of a Small Language
#   Model
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# 28 days ago
# •
# 34
# Team members
# 211
# +177
# +164
# +143
# +133
# +113
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 271k
# •
# 38
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 17.3M
# •
# •
# 618
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 720k
# •
# •
# 166
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 7.65M
# •
# •
# 688
# spaces
# 23
# Sort:
# 		Recently updated
# pinned
# Running
# 63
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 528
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Running
# 86
# Inference Playground
# 🔋
# Generate text in conversation with an AI model
# huggingface
# Dec 16, 2024
# Running
# 210
# paper-central
# ⚡
# Explore and manage research papers
# huggingface
# Dec 13, 2024
# Running
# on
# TPU v5e
# 8
# Keras Chatbot Battle
# 💬
# Interact with multiple chatbots simultaneously
# huggingface
# Dec 5, 2024
# Running
# 104
# Modelcard Creator
# ⚡
# Create and upload a Hugging Face model card
# huggingface
# Oct 26, 2024
# Expand 23
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 35
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 4.89k
# •
# •
# 56
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 57
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 49.2k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 288
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 22.6k
# •
# 5
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 3.33k
# •
# 18
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 66
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 34.6k
# •
# 76
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 32
# Sort:
# 		Recently updated
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 66
# •
# 380
# •
# 5
# huggingface/documentation-images
# Viewer
# •
# Updated
# 3 days ago
# •
# 50
# •
# 3.5M
# •
# 48
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 3 days ago
# •
# 1.56k
# •
# 667
# •
# 16
# huggingface/wiki_dpr
# Updated
# 12 days ago
# •
# 66
# huggingface/policy-docs
# Updated
# about 1 month ago
# •
# 2.27k
# •
# 8
# huggingface/paper-central-data
# Viewer
# •
# Updated
# Jan 4
# •
# 124k
# •
# 419
# •
# 8
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# Dec 22, 2024
# •
# 5.03k
# •
# 96
# •
# 7
# huggingface/my-distiset-3f5a230e
# Updated
# Nov 21, 2024
# •
# 18
# huggingface/cookbook-images
# Viewer
# •
# Updated
# Nov 14, 2024
# •
# 1
# •
# 44.6k
# •
# 6
# huggingface/vllm-metadata
# Updated
# Oct 8, 2024
# •
# 12
# Expand 32
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 285 models
# •
# 15.7k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 278 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 179 followers
# Writer
# Enterprise
# company
# •
# 18 models
# •
# 235 followers
# Xsolla
# Enterprise
# company
# •
# 92 followers
# Fidelity Investments
# Enterprise
# company
# •
# 124 followers
# Mistral AI_
# Enterprise
# company
# •
# 23 models
# •
# 5.25k followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.2k followers
# Chegg Inc
# Enterprise
# company
# •
# 82 followers
# Stability AI
# Enterprise
# company
# •
# 99 models
# •
# 15.8k followers
# Novo Nordisk
# Enterprise
# company
# •
# 43 followers
# Liberty Mutual
# Enterprise
# company
# •
# 43 followers
# Gretel.ai
# Enterprise
# company
# •
# 8 models
# •
# 96 followers
# BCG X
# Enterprise
# company
# •
# 32 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 26.8k followers
# AMD
# Enterprise
# company
# •
# 87 models
# •
# 1.3k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.57k followers
# Arm
# Enterprise
# company
# •
# 136 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 98 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 387 followers
# Procter & Gamble
# Enterprise
# company
# •
# 67 followers
# Aledade Inc
# Enterprise
# company
# •
# 60 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 60 followers
# Arcee AI
# Enterprise
# company
# •
# 147 models
# •
# 393 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 527 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 43 followers
# Kakao Corp.
# Enterprise
# company
# •
# 49 followers
# Adyen
# Enterprise
# company
# •
# 44 followers
# Shopify
# Enterprise
# company
# •
# 402 followers
# Snowflake
# Enterprise
# company
# •
# 14 models
# •
# 420 followers
# Together
# Enterprise
# company
# •
# 31 models
# •
# 516 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 175 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 122 followers
# Jusbrasil
# Enterprise
# company
# •
# 79 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 120 followers
# IBM Granite
# Enterprise
# company
# •
# 79 models
# •
# 1.02k followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 58 followers
# creditkarma
# Enterprise
# company
# •
# 45 followers
# Widn AI
# Enterprise
# company
# •
# 39 followers
# HiddenLayer
# Enterprise
# company
# •
# 54 followers
# StepFun
# Enterprise
# company
# •
# 4 models
# •
# 234 followers
# Ekimetrics
# Enterprise
# company
# •
# 51 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Higher rate limits for serverless inference
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# HF Inference API
# : Get x20 higher rate limits on HF Serverless API
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# Welcome Fireworks.ai on the Hub 🎆
# By
# julien-c
# February 14, 2025
# •
# 18
# Community Articles
# view all
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO)
# By
# prithivMLmods
# •
# about 1 hour ago
# •
# 3
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# about 1 hour ago
# WTF is Fine-Tuning? (intro4devs) | [2025]
# By
# tegridydev
# •
# about 11 hours ago
# •
# 1
# 🦸🏻#10: Does Present-Day GenAI Actually Reason?
# By
# Kseniase
# •
# 1 day ago
# •
# 5
# Blazing-Fast Code Editing via Multi-Layer Speculation
# By
# ganler
# and 3 others
# •
# 2 days ago
# •
# 15
# Argunauts: Open LLMs that Master Argument Analysis with Argdown
# By
# ggbetz
# •
# 3 days ago
# •
# 1
# Topic 27: What are Chain-of-Agents and Chain-of-RAG?
# By
# Kseniase
# and 1 other
# •
# 4 days ago
# •
# 8
# Adventures in AI
# By
# teksai
# •
# 4 days ago
# Agent Leaderboard: Evaluating AI Agents in Multi-Domain Scenarios
# By
# pratikbhavsar
# and 1 other
# •
# 5 days ago
# •
# 9
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# 5 days ago
# •
# 3
# **MindBot Ultra – Dreaming Edition: A Self-Building, Self-Aware AI for Synergistic Cognition and Autonomous Tool Generation**
# By
# TheMindExpansionNetwork
# •
# 6 days ago
# •
# 2
# Announcing the winners of the Frugal AI Challenge 🌱
# By
# frugal-ai-challenge
# and 1 other
# •
# 6 days ago
# •
# 6
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# 6 days ago
# •
# 6
# From Llasa to Llasagna 🍕: Finetuning LLaSA to generates Italian speech and other languages
# By
# Steveeeeeeen
# and 1 other
# •
# 6 days ago
# •
# 21
# Announcing AI Energy Score Ratings
# By
# sasha
# •
# 6 days ago
# •
# 25
# 🌁#87: Why DeepResearch Should Be Your New Hire
# By
# Kseniase
# •
# 6 days ago
# •
# 5
# Prompt Engineering in Multi-Agent Systems with KaibanJS
# By
# darielnoel
# •
# 7 days ago
# Fine-tune Deepseek-R1 with a Synthetic Reasoning Dataset
# By
# sdiazlor
# •
# 7 days ago
# •
# 31
# Open R1: Update #2
# By
# open-r1
# and 6 others
# •
# 7 days ago
# •
# 171
# Darija Chatbot Arena: Making LLMs Compete in the Moroccan Dialect
# By
# atlasia
# and 2 others
# •
# 7 days ago
# •
# 10
# Fixing Open LLM Leaderboard with Math-Verify
# By
# hynky
# February 14, 2025
# •
# 17
# 1 Billion Classifications
# By
# derek-thomas
# February 13, 2025
# guest
# •
# 35
# From Chunks to Blocks: Accelerating Uploads and Downloads on the Hub
# By
# jsulz
# February 12, 2025
# •
# 42
# Build awesome datasets for video generation
# By
# hlky
# February 12, 2025
# •
# 22
# The Open Arabic LLM Leaderboard 2
# By
# alielfilali01
# February 10, 2025
# guest
# •
# 25
# Open-source DeepResearch – Freeing our search agents
# By
# m-ric
# February 4, 2025
# •
# 997
# π0 and π0-FAST: Vision-Language-Action Models for General Robot Control
# By
# danaaubakirova
# February 4, 2025
# •
# 99
# DABStep: Data Agent Benchmark for Multi-step Reasoning
# By
# eggie5
# February 4, 2025
# guest
# •
# 47
# The AI tools for Art Newsletter - Issue 1
# By
# linoyts
# January 31, 2025
# •
# 52
# How to deploy and fine-tune DeepSeek models on AWS
# By
# pagezyhf
# January 30, 2025
# •
# 45
# Welcome to Inference Providers on the Hub 🔥
# By
# julien-c
# January 28, 2025
# •
# 369
# Open-R1: a fully open reproduction of DeepSeek-R1
# By
# eliebak
# January 28, 2025
# •
# 748
# State of open video generation models in Diffusers
# By
# sayakpaul
# January 27, 2025
# •
# 39
# We now support VLMs in smolagents!
# By
# m-ric
# January 24, 2025
# •
# 81
# Previous
# 1
# 2
# 3
# ...
# 38
# Next
# Community Articles
# view all
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO)
# By
# prithivMLmods
# •
# about 1 hour ago
# •
# 3
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# about 1 hour ago
# WTF is Fine-Tuning? (intro4devs) | [2025]
# By
# tegridydev
# •
# about 11 hours ago
# •
# 1
# 🦸🏻#10: Does Present-Day GenAI Actually Reason?
# By
# Kseniase
# •
# 1 day ago
# •
# 5
# Blazing-Fast Code Editing via Multi-Layer Speculation
# By
# ganler
# and 3 others
# •
# 2 days ago
# •
# 15
# Argunauts: Open LLMs that Master Argument Analysis with Argdown
# Image Generation
# Video Generation
# Text Generation
# Language Translation
# Speech Synthesis
# 3D Modeling
# Object Detection
# Text Analysis
# Image Editing
# Code Generation
# Question Answering
# Data Visualization
# Voice Cloning
# Background Removal
# Image Upscaling
# OCR
# Document Analysis
# Visual QA
# Image Captioning
# Chatbots
# Sentiment Analysis
# Text Summarization
# Music Generation
# Medical Imaging
# Financial Analysis
# Game AI
# Model Benchmarking
# Fine Tuning Tools
# Dataset Creation
# Pose Estimation
# Face Recognition
# Anomaly Detection
# Recommendation Systems
# Character Animation
# Style Transfer
# Image
# Spaces of the week
# Sort:
# 		Relevance
# Running
# on
# Zero
# 376
# Chat with DeepSeek-VL2-small
# 🌍
# Generate responses using images and text input
# deepseek-ai
# 8 days ago
# Running
# 254
# Kokoro Text-to-Speech (WebGPU)
# 🗣
# High-quality speech synthesis powered by Kokoro TTS
# webml-community
# 10 days ago
# Running
# on
# A10G
# 37
# Hibiki Simple
# 👄
# High-Fidelity Simultaneous Speech-To-Speech Translation
# fffiloni
# 7 days ago
# Running
# on
# CPU Upgrade
# 365
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# m-ric
# about 15 hours ago
# Running
# on
# Zero
# 27
# Granite Vision 3.1 2B
# 👀
# Chat with images and text for detailed responses
# shb777
# 3 days ago
# Running
# 16
# TinySwallow-1.5B-Instruct-WebGPU
# 🐦
# A compact Japanese LLM that runs locally in your browser.
# webml-community
# 12 days ago
# Running
# on
# Zero
# 82
# Lumina Image 2.0
# 🖼
# Generate images from text prompts
# Alpha-VLLM
# 7 days ago
# Running
# 19
# lm-similarity
# ☯
# Space for LM similarity on Open LLM Leaderboard data
# bethgelab
# 10 days ago
# All running apps, trending first
# Running
# on
# Zero
# 428
# LuminaBrush
# 📈
# Execute custom code from environment variable
# lllyasviel
# Dec 21, 2024
# Running
# on
# Zero
# 7.17k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# black-forest-labs
# Oct 9, 2024
# Running
# on
# CPU Upgrade
# 365
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# m-ric
# about 15 hours ago
# Running
# on
# Zero
# 1.62k
# Hunyuan3D-2.0
# 🌍
# Text-to-3D and Image-to-3D Generation
# tencent
# 20 days ago
# Running
# 254
# Kokoro Text-to-Speech (WebGPU)
# 🗣
# High-quality speech synthesis powered by Kokoro TTS
# webml-community
# 10 days ago
# Running
# on
# Zero
# 3.79k
# TRELLIS
# 🏢
# Scalable and Versatile 3D Generation from images
# JeffreyXiang
# Dec 18, 2024
# Running
# 146
# First Agent Template
# ⚡
# Find the current time in any timezone
# agents-course
# 4 days ago
# Running
# on
# Zero
# 1.76k
# Chat With Janus-Pro-7B
# 🌍
# A unified multimodal understanding and generation model.
# deepseek-ai
# 16 days ago
# Running
# on
# Zero
# 2.3k
# MIDJOURNEY
# 🏜
# MidJour | A RealVisXL_Turbo | IRL HI-Res Images Gen
# mukaist
# Jun 20, 2024
# Running
# on
# CPU Upgrade
# 7.42k
# Kolors Virtual Try-On
# 👕
# Try on garments on virtual models
# Kwai-Kolors
# Sep 18, 2024
# Running
# on
# CPU Upgrade
# 1.95k
# Anychat
# 🏢
# Browse and use coding demos from various providers
# akhaliq
# about 16 hours ago
# Running
# on
# Zero
# 376
# Chat with DeepSeek-VL2-small
# 🌍
# Generate responses using images and text input
# deepseek-ai
# 8 days ago
# Running
# on
# Zero
# 2.68k
# IC Light V2
# 📈
# Execute custom code from environment variable
# lllyasviel
# Oct 26, 2024
# Running
# on
# Zero
# 3.01k
# Live Portrait
# 🤪
# Apply the motion of a video on a portrait
# KwaiVGI
# Aug 30, 2024
# Running
# on
# CPU Upgrade
# 140
# Agent Leaderboard
# 💬
# Ranking of LLMs for agentic tasks
# galileo-ai
# 3 days ago
# Running
# on
# Zero
# 100
# Zonos
# 🌍
# Generate high-quality audio from text using various controls
# Steveeeeeeen
# 3 days ago
# Running
# on
# Zero
# 2.04k
# Kokoro TTS
# ❤
# Upgraded to v1.0!
# hexgrad
# 2 days ago
# Running
# on
# Zero
# 82
# Lumina Image 2.0
# 🖼
# Generate images from text prompts
# Alpha-VLLM
# 7 days ago
# Running
# on
# CPU Upgrade
# 95
# Unit 1 Quiz - AI Agent Fundementals
# 🔥
# Test your knowledge of the Agent fundamentals.
# agents-course
# 4 days ago
# Running
# on
# CPU Upgrade
# 4.8k
# MTEB Leaderboard
# 🥇
# Select and filter benchmarks for text embedding tasks
# mteb
# 12 days ago
# Running
# on
# CPU Upgrade
# 9.43k
# AI Comic Factory
# 👩
# Create your own AI comic with a single prompt
# jbilcke-hf
# Oct 15, 2024
# Running
# on
# CPU Upgrade
# 12.5k
# Open LLM Leaderboard
# 🏆
# Track, rank and evaluate open LLMs and chatbots
# open-llm-leaderboard
# 3 days ago
# Running
# on
# L4
# 1.37k
# MagicQuill
# 🪶
# AI4Editing
# 10 days ago
# Running
# 704
# FineWeb: decanting the web for the finest text data at scale
# 🍷
# Generate high-quality web text data for LLM training
# HuggingFaceFW
# Dec 18, 2024
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs

# %%
# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nWelcome to Inference Providers on the Hub 🔥\nsmolagents - a smol library to build great agents\nUse models from the HF Hub in LM Studio\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1\nUpdated\n8 days ago\n•\n3.98M\n•\n9.22k\nZyphra/Zonos-v0.1-hybrid\nUpdated\n2 days ago\n•\n12k\n•\n849\nagentica-org/DeepScaleR-1.5B-Preview\nUpdated\n6 days ago\n•\n8.91k\n•\n388\nmicrosoft/OmniParser-v2.0\nUpdated\n3 days ago\n•\n230\n•\n304\nZyphra/Zonos-v0.1-transformer\nUpdated\n2 days ago\n•\n30.5k\n•\n283\nBrowse 1M+ models\nSpaces\nRunning\non\nZero\n428\n428\nLuminaBrush\n📈\nExecute custom code from environment variable\nRunning\non\nZero\n7.17k\n7.17k\nFLUX.1 [dev]\n🖥\nGenerate images from text prompts\nRunning\non\nCPU Upgrade\n365\n365\nOpen Deep-Research\n🏆\nOpenAI's Deep Research, but open\nRunning\non\nZero\n1.62k\n1.62k\nHunyuan3D-2.0\n🌍\nText-to-3D and Image-to-3D Generation\nRunning\n254\n254\nKokoro Text-to-Speech (WebGPU)\n🗣\nHigh-quality speech synthesis powered by Kokoro TTS\nBrowse 400k+ applications\nDatasets\nopen-r1/OpenR1-Math-220k\nUpdated\n5 days ago\n•\n2.43k\n•\n313\nsaiyan-world/Goku-MovieGenBench\nUpdated\n6 days ago\n•\n19k\n•\n160\nopen-thoughts/OpenThoughts-114k\nUpdated\n3 days ago\n•\n52.3k\n•\n513\nAnthropic/EconomicIndex\nUpdated\n7 days ago\n•\n4.17k\n•\n129\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n9.6k\n•\n7.51k\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n388 models\n•\n2.26k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.57k followers\nAmazon Web Services\ncompany\n•\n20 models\n•\n2.72k followers\nGoogle\ncompany\n•\n913 models\n•\n7.61k followers\nIntel\ncompany\n•\n218 models\n•\n2.25k followers\nMicrosoft\ncompany\n•\n355 models\n•\n8.47k followers\nGrammarly\ncompany\n•\n10 models\n•\n125 followers\nWriter\nEnterprise\ncompany\n•\n18 models\n•\n235 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n139,097\nState-of-the-art ML for Pytorch, TensorFlow, and JAX.\nDiffusers\n27,473\nState-of-the-art diffusion models for image and audio generation in PyTorch.\nSafetensors\n3,090\nSimple, safe way to store and distribute neural networks weights safely and quickly.\nHub Python Library\n2,320\nClient library for the HF Hub: manage repositories from your Python runtime.\nTokenizers\n9,364\nFast tokenizers, optimized for both research and production.\nPEFT\n17,263\nParameter efficient finetuning method ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ## Welcome to Hugging Face!
# **The AI community building the future.** Hugging Face is the leading platform for machine learning collaboration, offering an extensive variety of models, datasets, and applications. Our mission is to democratize AI and promote community-driven development, making advanced tools available to everyone.
#
# ---
#
# ### Explore Our Offerings
# - **Models**: Browse and utilize over 1 million models tailored for various machine learning applications.
# - **Datasets**: Access and share an extensive library of over 250,000 datasets across a multitude of domains.
# - **Spaces**: Create and run applications seamlessly with our hosted environment.
# - **Enterprise Solutions**: Tailored compute and enterprise-grade support to catalyze your AI projects.
#
# ---
#
# ### Our Customers
# More than **50,000 organizations** trust Hugging Face to enhance their machine learning capabilities, including renowned names such as:
# - Amazon Web Services
# - Google
# - Microsoft
# - Meta
# - Grammarly
#
# Join a thriving ecosystem where companies leverage cutting-edge technology to innovate and excel.
#
# ---
#
# ### Company Culture
# At Hugging Face, we foster a culture centered around **collaboration** and **innovation**. Our goals include:
# - **Community-Driven**: We are committed to building an inclusive community where people can share knowledge, tools, and resources.
# - **Open Source**: Our commitment to open-source tools empowers developers and researchers to create and innovate freely.
# - **Continuous Learning**: We encourage our team and our community to pursue learning opportunities and expand their skill sets.
#
# ---
#
# ### Careers at Hugging Face
# Join our team and contribute to the evolution of AI! We are always on the lookout for talented individuals who are passionate about machine learning and community engagement.
#
# **Current Open Positions** include software developers, researchers, data scientists, and more. Embrace the opportunity to work in an agile environment, tackle challenges head-on, and shape the future of AI technology.
#
# ---
#
# ### Get Started Today!
# Ready to embark on your AI journey?
# - **Sign Up** for free at [Hugging Face](https://huggingface.co) and access a wealth of resources.
# - Collaborate, experiment, and build amazing applications that can impact the world.
#
# ---
#
# ### Connect With Us
# Stay updated and engage with our community:
# - [GitHub](https://github.com/HuggingFace)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/huggingface)
#
# Together, let’s build the future of AI.

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'posts page', 'url': 'https://huggingface.co/posts'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **"The AI community building the future."**
# Hugging Face is a leading platform in the machine learning community, empowering users to collaborate, discover, and create innovative AI models, datasets, and applications. With over 1 million models and 250,000 datasets available, we are your partner in advancing machine learning.
#
# ---
#
# ## Company Culture
# At Hugging Face, we foster an inclusive and collaborative culture that brings together AI enthusiasts, researchers, and developers. Our community-driven approach ensures that everyone can contribute to and benefit from advancements in machine learning. We believe in the power of open-source collaboration to innovate and enhance the AI landscape.
#
# - **Community-Driven:** We pride ourselves on our vibrant community, encouraging members to share knowledge and resources.
# - **Open Source:** Commitment to open-source principles allows our tools and models to be accessible to all.
# - **Continuous Learning:** We provide resources and an environment for ongoing education and skill development in AI and ML.
#
# ---
#
# ## Our Customers
# Hugging Face is trusted by over 50,000 organizations worldwide, including industry giants like:
# - **Meta**
# - **Google**
# - **Amazon Web Services**
# - **Microsoft**
# - **Grammarly**
#
# Our platform serves a diverse range of users from both enterprise businesses and non-profit organizations. Whether you are a researcher, developer, or enterprise team, Hugging Face offers tailored solutions to meet your needs.
#
# ---
#
# ## Careers at Hugging Face
# Join our dynamic team and help shape the future of AI. We are always on the lookout for innovative minds who are passionate about machine learning and willing to contribute to a community-driven culture.
#
# ### Current Opportunities
# - **Machine Learning Engineer**
# - **Data Scientist**
# - **Software Developer**
# - **Product Manager**
#
# Explore our careers page for open positions and join us in building the future of AI!
#
# ---
#
# ## Services We Provide
# ### For the Community
# - **Models & Datasets:** Host and collaborate on a vast array of models and datasets.
# - **Spaces:** A creative environment to run applications and generate content.
# - **Inference Endpoints:** Deploy models efficiently with optimized infrastructure.
#
# ### For Enterprises
# - **Compute Solutions:** Paid compute options starting at $0.60/hour.
# - **Enterprise Services:** Enhance your team's AI capabilities with dedicated support and security features starting at $20/user/month.
#
# ---
#
# ## Get Involved
# Whether you're looking to contribute to cutting-edge projects, utilize our vast resources, or join our growing team, Hugging Face invites you to be part of the AI revolution.
#
# - **[Join Us](https://huggingface.co)**
# - **Follow Us on [Twitter](https://twitter.com/huggingface)** and [LinkedIn](https://www.linkedin.com/company/hugging-face)
# - **Engage with the community on [Discord](https://discord.gg/huggingface)**
#
# ### Together, let’s shape the future of AI!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **The AI community building the future.**
#
# At Hugging Face, we are at the forefront of the AI and machine learning revolution. Our innovative platform fosters collaboration among developers, researchers, and enterprises, making it the go-to hub for sharing models, datasets, and applications.
#
# ## What We Offer
# - **1M+ Models**: Explore our extensive library of machine learning models across various applications including text, image, audio, and more.
# - **250k+ Datasets**: Access a comprehensive collection of datasets to supercharge your machine learning projects.
# - **Spaces**: Run and share your applications in an interactive environment.
# - **Enterprise Solutions**: Tailored solutions that combine advanced technology with enterprise-grade security and dedicated support.
#
# ## Company Culture
# At Hugging Face, we emphasize **community** and **innovation**. We believe in the power of collaboration, and our open-source philosophy drives us to build tools and resources with input from our vibrant community. Our values are rooted in transparency, respect, and a commitment to making AI accessible to everyone.
#
# ## Who We're Proud to Work With
# Join over **50,000 organizations** like:
# - **AI at Meta**
# - **Amazon Web Services**
# - **Google**
# - **Microsoft**
#
# These partnerships reflect our credibility and dedication to advancing the field of artificial intelligence.
#
# ## Career Opportunities
# Looking to build a career in AI? Hugging Face is constantly seeking talented individuals who are passionate about machine learning and open-source development. Explore roles in various domains, from software engineering to research, and become an integral part of our mission to shape the future of AI.
#
# **Join us** and empower the ML community!
#
# ## Get Started Today
# Whether you're a developer looking to enhance your portfolio, a researcher wanting to explore top-notch tools, or a business aiming to leverage AI, **Hugging Face** has the resources you need.
#
# - **Visit our Website**: [Hugging Face](https://huggingface.co)
#
# ### Follow Us
# Stay connected with us through our social channels:
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# ---
#
# Together, let’s advance artificial intelligence and make it accessible to all!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
